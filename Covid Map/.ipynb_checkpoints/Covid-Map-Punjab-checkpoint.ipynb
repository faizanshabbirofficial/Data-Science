# %%
import folium as fo
import pandas as pd

# %%
punjab_map = fo.Map(location = [30.85, 72.31], zoom_start = 7, tiles = 'OpenStreetMap')

# %%
punjab_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f106844f55acdbd2989cdd5059cb1d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f106844f55acdbd2989cdd5059cb1d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f106844f55acdbd2989cdd5059cb1d2 = L.map(
#                 &quot;map_4f106844f55acdbd2989cdd5059cb1d2&quot;,
#                 {
#                     center: [30.85, 72.31],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_24577e301cdfa1398db9c1a0fd5221fc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4f106844f55acdbd2989cdd5059cb1d2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df = pd.read_csv("Covid-Data.csv")
df
# Out:
#           City  Latitude  Longitude  Total Cases  Deaths  Recoveries  \
# 0       Lahore   31.5204    74.3587        40000    1200       28000
# 1       Multan   30.1575    71.5249        22000     800       21200
# 2   Gujranwala   32.1877    74.1945        20000     900       19100
# 3        Kasur   31.1179    74.4408        17000    1000       18000
# 4   Rawalpindi   33.5651    73.0169        12000     200       11800
# 5  Sheikhupura   31.7167    73.9850        10000     300        9700
# 6       Jhelum   32.9425    73.7257         6500     300        3500
#
#    Active Cases
# 0           780
# 1           430
# 2           450
# 3           200
# 4           320
# 5           390
# 6           280

# %%
total = 0
for cases in df['Total Cases']:
    total = int(cases) + int(total)

# %%
for city, lat, long, tc, de, re, ac in zip(list(df['City']),list(df['Latitude']),list(df['Longitude']),list(df['Total Cases']),list(df['Deaths']),list(df['Recoveries']),list(df['Active Cases'])):
    fo.CircleMarker(location = [lat,long], radius = (tc/total)*100, color='red', fill = False, fill_color = 'blue').add_to(punjab_map)
    htmlData = 'Total Cases: ' + str(tc) + '' + 'Deaths: '+ str(de) + '' + 'Recoveries: ' + str(re) + '' + 'Active Cases: ' + str(ac)
    iframe = fo.IFrame(htmlData, width=200, height=150)
    popupData = fo.Popup(iframe, max_width=500)
    fo.Marker(location = [lat,long], popup=popupData).add_to(punjab_map)

# %%
punjab_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f106844f55acdbd2989cdd5059cb1d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f106844f55acdbd2989cdd5059cb1d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f106844f55acdbd2989cdd5059cb1d2 = L.map(
#                 &quot;map_4f106844f55acdbd2989cdd5059cb1d2&quot;,
#                 {
#                     center: [30.85, 72.31],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_24577e301cdfa1398db9c1a0fd5221fc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4f106844f55acdbd2989cdd5059cb1d2);
#
#
#             var circle_marker_bf229008822505d88203dfadd9bea264 = L.circleMarker(
#                 [31.5204, 74.3587],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 31.372549019607842, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4f106844f55acdbd2989cdd5059cb1d2);
#
#
#             var marker_e59055d329158e442ec72f336ab8fdf1 = L.marker(
#                 [31.5204, 74.3587],
#                 {}
#             ).addTo(map_4f106844f55acdbd2989cdd5059cb1d2);
#
#
#         var popup_37da616406d582be163d07c5481d85c2 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var i_frame_1ff18c6e5d20dd25ea36e30bd61e222a = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBUb3RhbCBDYXNlczogNDAwMDBEZWF0aHM6IDEyMDBSZWNvdmVyaWVzOiAyODAwMEFjdGl2ZSBDYXNlczogNzgw&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_37da616406d582be163d07c5481d85c2.setContent(i_frame_1ff18c6e5d20dd25ea36e30bd61e222a);
#
#
#
#         marker_e59055d329158e442ec72f336ab8fdf1.bindPopup(popup_37da616406d582be163d07c5481d85c2)
#         ;
#
#
#
#
#             var circle_marker_483190a958d746007a62662864f7d0e2 = L.circleMarker(
#                 [30.1575, 71.5249],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 17.254901960784313, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4f106844f55acdbd2989cdd5059cb1d2);
#
#
#             var marker_8ec8f4f652965a559a9fdb51aed6c2e6 = L.marker(
#                 [30.1575, 71.5249],
#                 {}
#             ).addTo(map_4f106844f55acdbd2989cdd5059cb1d2);
#
#
#         var popup_65dcd603af8f903eb40a18c045959750 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var i_frame_45908f05ed42fd35ab88d73d98603fe4 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBUb3RhbCBDYXNlczogMjIwMDBEZWF0aHM6IDgwMFJlY292ZXJpZXM6IDIxMjAwQWN0aXZlIENhc2VzOiA0MzA=&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_65dcd603af8f903eb40a18c045959750.setContent(i_frame_45908f05ed42fd35ab88d73d98603fe4);
#
#
#
#         marker_8ec8f4f652965a559a9fdb51aed6c2e6.bindPopup(popup_65dcd603af8f903eb40a18c045959750)
#         ;
#
#
#
#
#             var circle_marker_6754ceaaa313c580af6a07b36c9d60bf = L.circleMarker(
#                 [32.1877, 74.1945],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.686274509803921, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4f106844f55acdbd2989cdd5059cb1d2);
#
#
#             var marker_59666dfcf029b9d1b83d8b7f915ab4ef = L.marker(
#                 [32.1877, 74.1945],
#                 {}
#             ).addTo(map_4f106844f55acdbd2989cdd5059cb1d2);
#
#
#         var popup_6073e329eb09a981404fd2a2bb4dc33b = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var i_frame_34f60f214b178d7b4f3a91d73244522f = $(`&lt;if
